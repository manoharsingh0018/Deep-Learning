# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sn

# %%
df = pd.read_csv("sonar_dataset.csv", header = None)
df.sample(5)
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 176  0.0635  0.0709  0.0453  0.0333  0.0185  0.1260  0.1015  0.1918  0.3362
# 9    0.0164  0.0173  0.0347  0.0070  0.0187  0.0671  0.1056  0.0697  0.0962
# 84   0.0378  0.0318  0.0423  0.0350  0.1787  0.1635  0.0887  0.0817  0.1779
# 185  0.0340  0.0625  0.0381  0.0257  0.0441  0.1027  0.1287  0.1850  0.2647
# 79   0.0108  0.0086  0.0058  0.0460  0.0752  0.0887  0.1015  0.0494  0.0472
#
#          9   ...      51      52      53      54      55      56      57  \
# 176  0.3900  ...  0.0048  0.0025  0.0087  0.0072  0.0095  0.0086  0.0085
# 9    0.0251  ...  0.0090  0.0223  0.0179  0.0084  0.0068  0.0032  0.0035
# 84   0.2053  ...  0.0046  0.0044  0.0078  0.0102  0.0065  0.0061  0.0062
# 185  0.4117  ...  0.0141  0.0019  0.0067  0.0099  0.0042  0.0057  0.0051
# 79   0.0393  ...  0.0029  0.0078  0.0114  0.0083  0.0058  0.0003  0.0023
#
#          58      59  60
# 176  0.0040  0.0051   M
# ...

# %%
df.shape
# Out:
# (208, 61)

# %%
df.isna().sum()
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 56    0
# 57    0
# 58    0
# 59    0
# 60    0
# Length: 61, dtype: int64

# %%
df[60].value_counts()
# Out:
# M    111
# R     97
# Name: 60, dtype: int64

# %%
X = df.drop(60, axis = 'columns')
y = df[60]
X
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
y = pd.get_dummies(y, drop_first = True)
y.sample(5) # R= 1 and M = 0
# Out:
#      R
# 145  0
# 167  0
# 12   1
# 59   1
# 164  0

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train,y_test = train_test_split(X, y, test_size = 0.25, random_state = 1)

# %%
X_train.shape, X_test.shape
# Out:
# ((156, 60), (52, 60))

# %%
import tensorflow as tf
from tensorflow import keras

# %%
model = keras.Sequential([
    keras.layers.Dense(60, input_dim = 60, activation = 'relu'),
    keras.layers.Dense(15, activation = 'relu'),
    keras.layers.Dense(1, activation = 'sigmoid')
])

model.compile(optimizer = 'adam',
              loss = 'binary_crossentropy',
             metrics = ['accuracy'])

model.fit(X_train, y_train, epochs = 100, batch_size = 8)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 1s 2ms/step - loss: 0.6812 - accuracy: 0.5524
# Epoch 2/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6498 - accuracy: 0.6684
# Epoch 3/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6501 - accuracy: 0.6843
# Epoch 4/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6156 - accuracy: 0.7007
# Epoch 5/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5929 - accuracy: 0.7776
# Epoch 6/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5841 - accuracy: 0.7594
# Epoch 7/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5713 - accuracy: 0.7963
# Epoch 8/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5523 - accuracy: 0.7978
# Epoch 9/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5121 - accuracy: 0.7954
# Epoch 10/100
# ...

# %%
#we achieved an accuracy of model of 100%
model.evaluate(X_test, y_test)
# Out:
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6849 - accuracy: 0.7115
# [0.6848822236061096, 0.7115384340286255]

# %%
y_pred = model.predict(X_test).reshape(-1)
print(y_pred[:10])

y_pred = np.round(y_pred)
print(y_pred[:10])
print(y_test[:10])
# Out:
# [2.0673392e-07 8.6102414e-01 9.1030514e-01 4.3849086e-05 9.9995255e-01
#  9.7630906e-01 6.7366695e-01 9.9998385e-01 9.5156029e-05 9.9998510e-01]
# [0. 1. 1. 0. 1. 1. 1. 1. 0. 1.]
#      R
# 186  0
# 155  0
# 165  0
# 200  0
# 58   1
# 34   1
# 151  0
# 18   1
# 202  0
# 62   1

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.85      0.75        27
#            1       0.78      0.56      0.65        25
#
#     accuracy                           0.71        52
#    macro avg       0.73      0.71      0.70        52
# weighted avg       0.73      0.71      0.70        52

# %%
#dropout regulariszation
model = keras.Sequential([
    keras.layers.Dense(60, input_dim = 60, activation = 'relu'),
    keras.layers.Dropout(0.5),#0.5 represent dropout factor that is 0.5 means 50%neuron will drop
    keras.layers.Dense(30, activation = 'relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(15, activation = 'relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1, activation = 'sigmoid')
])

model.compile(optimizer = 'adam',
              loss = 'binary_crossentropy',
             metrics = ['accuracy'])

model.fit(X_train, y_train, epochs = 100, batch_size = 8)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 1s 2ms/step - loss: 0.6939 - accuracy: 0.5620
# Epoch 2/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7481 - accuracy: 0.5094
# Epoch 3/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6640 - accuracy: 0.6443
# Epoch 4/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6734 - accuracy: 0.5250
# Epoch 5/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6982 - accuracy: 0.5256
# Epoch 6/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7132 - accuracy: 0.4492
# Epoch 7/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6873 - accuracy: 0.6093
# Epoch 8/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7197 - accuracy: 0.4771
# Epoch 9/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6895 - accuracy: 0.5264
# Epoch 10/100
# ...

# %%
model.evaluate(X_test, y_test)
# Out:
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3348 - accuracy: 0.8462
# [0.33479276299476624, 0.8461538553237915]

# %%
y_pred1 = model.predict(X_test).reshape(-1)
print(y_pred1[:10])

y_pred1 = np.round(y_pred1)
print(y_pred1[:10])
print(y_test[:10])
# Out:
# [1.1892553e-04 7.4286771e-01 8.9970398e-01 2.0124584e-02 9.9856341e-01
#  9.4418359e-01 2.9579338e-01 9.9758184e-01 1.1152536e-02 9.9951732e-01]
# [0. 1. 1. 0. 1. 1. 0. 1. 0. 1.]
#      R
# 186  0
# 155  0
# 165  0
# 200  0
# 58   1
# 34   1
# 151  0
# 18   1
# 202  0
# 62   1

# %%
print(classification_report(y_test,y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86        27
#            1       0.87      0.80      0.83        25
#
#     accuracy                           0.85        52
#    macro avg       0.85      0.84      0.85        52
# weighted avg       0.85      0.85      0.85        52
